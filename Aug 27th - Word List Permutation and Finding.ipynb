# %%
#Given a string s and a list of words words, where each word is the same length, find all starting
#indices of substrings in s that is a concatenation of every word in words exactly once.

#For example, given s = "dogcatcatcodecatdog" and words = ["cat", "dog"], return [0, 13], since 
#"dogcat" starts at index 0 and "catdog" starts at index 13.

#Given s = "barfoobazbitbyte" and words = ["dog", "cat"], return [] since there are no substrings composed of "dog" and "cat" in s.

#The order of the indices does not matter.

# %%
#1. create all combination of all word list with recursive model

#2. iterate through every word in the list of combination and see what are 

#3. for each position identify it and append that to a list

# %%
from itertools import permutations
def word_combo(list):
    combos = []
    for i in list:
        word_list = permutations(list, len(list))
    for wordcombo in word_list:
        combos.append(''.join(wordcombo))  
    return combos

# %%
word_combo(["cat", "dog"])
# Out:
# ['catdog', 'dogcat']

# %%
def seek_loc(list, string):
    from itertools import permutations
    def word_combo(list):
        combos = []
        for i in list:
            word_list = permutations(list, len(list))
        for wordcombo in word_list:
            combos.append(''.join(wordcombo))  
        return combos

    location = []
    combos = word_combo(list)
    for combo in combos:
        loc = string.find(combo)
        location.append(loc)
        if loc >0:
            return location
        else:
            return []

# %%
 seek_loc(["cat", "dog"], "barfoobazbitbyte")
# Out:
# []
