# %%
#Given a list of integers and a number K, return which contiguous elements of the list sum to K.

#For example, if the list is [1, 2, 3, 4, 5] and K is 9, then it should return [2, 3, 4], since 2 + 3 + 4 = 9.

# %%
def consect_return(data, sum):
    if sum(n, n+1, n+2, n+
           sum - n
           for i in data:
           if i < sum:
           if i,i+1,+i+x = sum
           
           
           i
           i+1
           i+1+1
           i+1+1+1

# %%
def consect_return(data, tot):
    consec = []
    sortedlist = sorted(data)
    sum = 0
    for i in range(len(sortedlist)-1):
        sum += sortedlist[i]
        consec.append(sortedlist[i])
        if sum == tot:
            return consec

# %%
consect_return([2,3,4,5,6], 5)
# Out:
# [2, 3]
